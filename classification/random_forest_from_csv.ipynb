# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # 학습을 위한 데이터(csv) 불러오기
# - csv파일로 정리된 데이터를 가져옵니다.

# %%
data = pd.read_csv('results0410_m.csv')

# %% [markdown]
# - fillna(0)는 NaN인 데이터를 0으로 채우라는 것입니다. 데이터의 규모가 크지 않다면 csv파일을 미리 검토하여, 숫자가 아닌 데이터를 적절한 값으로 변경해주는 것이 좋습니다. 적절하지 못하거나 누락된 데이터를 다루는 방법은 다양하지만 여기서는 0을 채울 것 입니다.

# %%
data = data.fillna(0)
data[:4]
# Out:
#    Patient ID  Label  original_firstorder_10Percentile  \
# 0    10507209      3                        -46.477375
# 1    11038454      3                        -34.419225
# 2    11117389      1                        -34.940415
# 3    11493583      2                        -19.402685
#
#    original_firstorder_90Percentile  original_firstorder_Energy  \
# 0                        258.599425                1.049258e+10
# 1                        193.972930                8.092486e+10
# 2                        145.752348                4.537091e+10
# 3                        522.313469                8.550332e+08
#
#    original_firstorder_Entropy  original_firstorder_InterquartileRange  \
# 0                     6.288854                              205.941402
# 1                     5.926278                              138.825455
# 2                     5.808166                              100.146822
# 3                     7.022576                              305.881341
#
#    original_firstorder_Kurtosis  original_firstorder_Maximum  \
# 0                      1.931149                   469.641244
# 1                      2.122706                   461.369427
# 2                      3.299762                   428.314010
# 3                      2.335018                   821.665003
#
#    original_firstorder_Mean  ...  \
# 0                108.119006  ...
# 1                 64.961432  ...
# 2                 46.879163  ...
# 3                212.933828  ...
#
#    log-sigma-5-0-mm-3D_glszm_LargeAreaLowGrayLevelEmphasis  \
# 0                                           6.437638
# 1                                         517.399532
# 2                                         468.503301
# 3                                           0.530733
#
#    log-sigma-5-0-mm-3D_glszm_LowGrayLevelZoneEmphasis  \
# 0                                           0.002342
# 1                                           0.002807
# 2                                           0.002494
# 3                                           0.005230
#
#    log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformity  \
# 0                                      1216.548156
# 1                                      2625.905057
# 2                                      1116.406621
# 3                                       195.537517
#
#    log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformityNormalized  \
# 0                                           0.189287
# 1                                           0.160950
# 2                                           0.157952
# 3                                           0.266763
#
#    log-sigma-5-0-mm-3D_glszm_SmallAreaEmphasis  \
# 0                                     0.428052
# 1                                     0.393305
# 2                                     0.390830
# 3                                     0.523720
#
#    log-sigma-5-0-mm-3D_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                         356.782181
# 1                                         239.910789
# 2                                         288.516460
# 3                                         294.065533
#
#    log-sigma-5-0-mm-3D_glszm_SmallAreaLowGrayLevelEmphasis  \
# 0                                           0.000875
# 1                                           0.001047
# 2                                           0.000996
# 3                                           0.002938
#
#    log-sigma-5-0-mm-3D_glszm_ZoneEntropy  \
# 0                               8.269472
# 1                               8.429233
# 2                               8.492476
# 3                               7.042645
#
#    log-sigma-5-0-mm-3D_glszm_ZonePercentage  \
# 0                                  0.110195
# 1                                  0.028294
# 2                                  0.019557
# 3                                  0.260206
#
#    log-sigma-5-0-mm-3D_glszm_ZoneVariance
# 0                             1826.995332
# 1                           364993.878900
# 2                           327829.551700
# 3                               53.982207
#
# [4 rows x 1134 columns]

# %% [markdown]
# ## Data(X)와 Label(y)을 나누기
# - 항목이름이 'Label'인 데이터를 y로 가져오고, Patient ID와 같이 학습에 활용되지 않는 데이터는 제외하고, X를 데이터로 만듭니다.
# - .pop은 빼서 다른 변수에 저장하는 것. 'Patient ID'외에도 fitting에 사용할 필요없는 변수들은 .pop이나 .drop으로 빼주도록 합니다.

# %%
y = data.pop('Label')
y[:4]
# Out:
# 0    3
# 1    3
# 2    1
# 3    2
# Name: Label, dtype: int64

# %%
pid = data.pop('Patient ID')
pid[:4]
# Out:
# 0    10507209
# 1    11038454
# 2    11117389
# 3    11493583
# Name: Patient ID, dtype: int64

# %%
X = data
X[:4]
# Out:
#    original_firstorder_10Percentile  original_firstorder_90Percentile  \
# 0                        -46.477375                        258.599425
# 1                        -34.419225                        193.972930
# 2                        -34.940415                        145.752348
# 3                        -19.402685                        522.313469
#
#    original_firstorder_Energy  original_firstorder_Entropy  \
# 0                1.049258e+10                     6.288854
# 1                8.092486e+10                     5.926278
# 2                4.537091e+10                     5.808166
# 3                8.550332e+08                     7.022576
#
#    original_firstorder_InterquartileRange  original_firstorder_Kurtosis  \
# 0                              205.941402                      1.931149
# 1                              138.825455                      2.122706
# 2                              100.146822                      3.299762
# 3                              305.881341                      2.335018
#
#    original_firstorder_Maximum  original_firstorder_Mean  \
# 0                   469.641244                108.119006
# 1                   461.369427                 64.961432
# 2                   428.314010                 46.879163
# 3                   821.665003                212.933828
#
#    original_firstorder_MeanAbsoluteDeviation  original_firstorder_Median  ...  \
# 0                                 100.628664                  108.113241  ...
# 1                                  72.110523                   50.306098  ...
# 2                                  58.118038                   35.856661  ...
# 3                                 168.082255                  171.534056  ...
#
#    log-sigma-5-0-mm-3D_glszm_LargeAreaLowGrayLevelEmphasis  \
# 0                                           6.437638
# 1                                         517.399532
# 2                                         468.503301
# 3                                           0.530733
#
#    log-sigma-5-0-mm-3D_glszm_LowGrayLevelZoneEmphasis  \
# 0                                           0.002342
# 1                                           0.002807
# 2                                           0.002494
# 3                                           0.005230
#
#    log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformity  \
# 0                                      1216.548156
# 1                                      2625.905057
# 2                                      1116.406621
# 3                                       195.537517
#
#    log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformityNormalized  \
# 0                                           0.189287
# 1                                           0.160950
# 2                                           0.157952
# 3                                           0.266763
#
#    log-sigma-5-0-mm-3D_glszm_SmallAreaEmphasis  \
# 0                                     0.428052
# 1                                     0.393305
# 2                                     0.390830
# 3                                     0.523720
#
#    log-sigma-5-0-mm-3D_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                         356.782181
# 1                                         239.910789
# 2                                         288.516460
# 3                                         294.065533
#
#    log-sigma-5-0-mm-3D_glszm_SmallAreaLowGrayLevelEmphasis  \
# 0                                           0.000875
# 1                                           0.001047
# 2                                           0.000996
# 3                                           0.002938
#
#    log-sigma-5-0-mm-3D_glszm_ZoneEntropy  \
# 0                               8.269472
# 1                               8.429233
# 2                               8.492476
# 3                               7.042645
#
#    log-sigma-5-0-mm-3D_glszm_ZonePercentage  \
# 0                                  0.110195
# 1                                  0.028294
# 2                                  0.019557
# 3                                  0.260206
#
#    log-sigma-5-0-mm-3D_glszm_ZoneVariance
# 0                             1826.995332
# 1                           364993.878900
# 2                           327829.551700
# 3                               53.982207
#
# [4 rows x 1132 columns]

# %% [markdown]
# ## Validation set을 나누고, model의 파라미터들을 설정하기
# - ML model의 overfitting과 관련하여 data의 일부를 validation set을 빼서 validation set의 accuracy를 관찰하는 것이 좋습니다.
# - test_size = 0.25의 0.25를 적절한 비율로 변경하면 됩니다. 이 경우 25%의 데이터를 빼게 됩니다.
# - class imbalance가 심한 경우에는 아래의 방법을 그대로 쓰는 것을 권장하지 않습니다. 관련해서는 추후 업데이트 예정
# - RandomForestClassifier는 n_estimators, max_depth등 다양한 파라미터들을 가지고 이에 따라 결과가 달라지는 것을 주의합니다.

# %%
seed=np.random.randint(42)
#seed=42
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.25,random_state=seed)

# %%
clf = RandomForestClassifier(n_estimators = 50, max_depth=3,random_state=seed)

# %% [markdown]
# ## Model을 학습시키기

# %%
clf.fit(X_train,y_train)

# clf.fit(X,y)  # <- validation set을 나누지 않고 model을 학습시키고자 하면...
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=3, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50,
#                        n_jobs=None, oob_score=False, random_state=40, verbose=0,
#                        warm_start=False)

# %% [markdown]
# ## Validation set에 대한 예측결과를 출력하기

# %%
p_valid = clf.predict(X_valid)
p_valid
# Out:
# array([1, 1, 1, 1, 2, 1, 3, 3, 3, 1, 3, 3, 1, 3, 1, 2, 1, 1])

# %%
d={'label':y_valid,'prediction':p_valid}

# %%
r_valid = pd.DataFrame(data=d)
r_valid
# Out:
#     label  prediction
# 45      1           1
# 0       3           1
# 63      3           1
# 52      3           1
# 26      2           2
# 21      3           1
# 4       3           3
# 24      2           3
# 68      2           3
# 38      1           1
# 17      1           3
# 6       3           3
# 43      1           1
# 39      3           3
# 47      2           1
# 20      1           2
# 61      1           1
# 42      3           1

# %%
confusion_matrix(y_valid,p_valid,labels=[1,2,3])
# Out:
# array([[4, 1, 1],
#        [1, 1, 2],
#        [5, 0, 3]])

# %% [markdown]
# # 새로운 데이터(csv)를 평가하기
# - 학습된 모델을 새로운 데이터를 평가하기 위해, 같은 포맷으로 만들어진 별도의 csv파일을 불러옵니다.(여기서는 예제에서는 작동하는 것을 보기 위해 훈련에 사용한 csv파일을 다시 불러오는 것이지만...)
# - predict_proba는 각각의 label에 대한 output의 probability를 나타냅니다. 이는 ROC curve같은 것을 그릴 때에 활용될 수 있습니다.
# - 결과는 to_csv를 이용해 csv파일로 저장할 수 있습니다.

# %%
data = pd.read_csv('results0410_m.csv')
data = data.fillna(0)
y_test = data.pop('Label')
pid = data.pop('Patient ID')
X_test = data
p_test = clf.predict(X_test)
prob_test = clf.predict_proba(X_test)
d={'ID':pid,'label':y_test,'prediction':p_test,'prob1':prob_test[:,0],'prob2':prob_test[:,1],'prob3':prob_test[:,2]}
r_test = pd.DataFrame(data=d)
r_test[:4]
# Out:
#          ID  label  prediction     prob1     prob2     prob3
# 0  10507209      3           1  0.630152  0.065763  0.304085
# 1  11038454      3           3  0.392145  0.012530  0.595324
# 2  11117389      1           1  0.635824  0.012950  0.351226
# 3  11493583      2           2  0.073333  0.900920  0.025747

# %%
r_test.to_csv('test_results.csv')

# %%
confusion_matrix(y_test,p_test,labels=[1,2,3])
# Out:
# array([[29,  1,  1],
#        [ 1, 11,  2],
#        [ 5,  0, 22]])
